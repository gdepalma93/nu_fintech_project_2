# %%
# Initial Imports
import pandas as pd
import numpy as np
from pathlib import Path
from dotenv import load_dotenv
import time
from joblib import dump,load # Save Models
from numpy import random
import os
from datetime import date, datetime, timedelta
import matplotlib.pyplot as plt

# SDK Imports
import tweepy
import shrimpy
from newsapi import NewsApiClient
import cryptocompare

# NLP Models
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
#from ibm_watson import ToneAnalyzerV3
#from ibm_cloud_sdk.authenticators import IAMAuthenticator
# SKLearn Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
#from sklearn.preprocessing import StandardScaler, MinMaxScalar
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# Tensor Flow Models
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import LSTM, Dense, Dropout

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# HV Plot
#import hvplot.pandas
#import panel as pn
#from plotly.express as px
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\GrantDePalma\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Set environment variables from the .env file
env_path = Path("/Users/GrantDePalma")/'.env'
load_dotenv(env_path)


# Extract API Keys from environment variables

shrimpy_public_key = os.getenv("SHRIMPY_PUBLIC_KEY")
shrimpy_private_key = os.getenv("SHRIMPY_PRIVATE_KEY")
TWITTER_API_KEY = os.getenv("TWITTER_API_KEY")
TWITTER_API_SECRET_KEY = os.getenv("TWITTER_API_SECRET_KEY")
TWITTER_ACCESS_TOKEN = os.getenv("TWITTER_ACCESS_TOKEN")
TWITTER_ACCESS_TOKEN_SECRET = os.getenv("TWITTER_ACCESS_TOKEN_SECRET")
KRAKEN_API_KEY = os.getenv("KRAKEN_API_KEY")
KRAKEN_PRIVATE_KEY = os.getenv("KRAKEN_PRIVATE_KEY")
#BITTREX_PRIVATE_KEY = 
#BITTREX_PUBLIC_KEY =

# %%
# Twitter API client
auth_twitter = tweepy.OAuthHandler(TWITTER_API_KEY, TWITTER_API_SECRET_KEY)
auth_twitter.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
twitter_client = tweepy.API(auth_twitter)

# Shrimpy API Client
shrimpy_client = shrimpy.ShrimpyApiClient(shrimpy_public_key, shrimpy_private_key)

# News API Client
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %% [markdown]
# ## Data Pre-Processing

# %%
kraken_pairs = shrimpy_client.get_trading_pairs('kraken')
kraken_pairs_df = pd.DataFrame(columns=['base','quote'])
for key, value in enumerate(kraken_pairs):
    kraken_pairs_df.loc[key] = [value['baseTradingSymbol'],value['quoteTradingSymbol']]
kraken_pairs_df_2 = kraken_pairs_df.head(10)

# %%
# ## Candles
def get_prices(kraken_pairs_df, interval, starttime):
    master_prices_df = pd.DataFrame()
    time = []
    prices = []
    for index, row in kraken_pairs_df.iterrows():
        candles = shrimpy_client.get_candles('kraken', row['base'], row['quote'], interval, starttime)
        for key, value in enumerate(candles):
            #prices_df.loc[key] = [pd.to_datetime(value['time']), value['close']]
            time.append(value['time'])
            prices.append(value['close'])
            prices_df = pd.DataFrame(list(zip(time, prices)), columns = ['time', row['base']+ "_" + row['quote']])
        if master_prices_df.empty:
            master_prices_df = prices_df
        else:
            master_prices_df = pd.merge(master_prices_df, prices_df, on='time', how='left')        
    return master_prices_df

# %%
df_candles = get_prices(kraken_pairs_df_2, '1m', '2016-01-01')

# %%
df_candles.head()
# Out:
#                        time             ADA_ETH             ADA_EUR  \
# 0  2020-08-06T06:59:47.000Z  0.0003579000000000  0.0003579000000000
# 1  2020-08-06T07:09:32.000Z  0.0003572000000000  0.0003572000000000
# 2  2020-08-06T07:09:32.000Z  0.0003572000000000  0.0003572000000000
# 3  2020-08-06T07:09:32.000Z  0.0003572000000000  0.0003572000000000
# 4  2020-08-06T07:09:32.000Z  0.0003572000000000  0.0003572000000000
#
#               ADA_USD             ADA_XBT            ALGO_ETH  \
# 0  0.0003579000000000  0.0003579000000000  0.0003579000000000
# 1  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 2  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 3  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 4  0.0003572000000000  0.0003572000000000  0.0003572000000000
#
#              ALGO_EUR            ALGO_USD            ALGO_XBT  \
# 0  0.0003579000000000  0.0003579000000000  0.0003579000000000
# 1  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 2  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 3  0.0003572000000000  0.0003572000000000  0.0003572000000000
# 4  0.0003572000000000  0.0003572000000000  0.0003572000000000
#
#              ATOM_ETH            ATOM_EUR
# 0  0.0003579000000000  0.0003579000000000
# 1  0.0003572000000000  0.0003572000000000
# 2  0.0003572000000000  0.0000121700000000
# 3  0.0000121700000000  0.0003572000000000
# 4  0.0000121700000000  0.0000121700000000

# %%
df_candles_t = df_candles.set_index('time')
df_candles_stack = df_candles_t.stack().to_frame(name='price')
df_candles_stack.head(20)
# Out:
#                                                 price
# time
# 2020-08-06T06:59:47.000Z ADA_ETH   0.0003579000000000
#                          ADA_EUR   0.0003579000000000
#                          ADA_USD   0.0003579000000000
#                          ADA_XBT   0.0003579000000000
#                          ALGO_ETH  0.0003579000000000
#                          ALGO_EUR  0.0003579000000000
#                          ALGO_USD  0.0003579000000000
#                          ALGO_XBT  0.0003579000000000
#                          ATOM_ETH  0.0003579000000000
#                          ATOM_EUR  0.0003579000000000
# 2020-08-06T07:09:32.000Z ADA_ETH   0.0003572000000000
#                          ADA_EUR   0.0003572000000000
#                          ADA_USD   0.0003572000000000
#                          ADA_XBT   0.0003572000000000
#                          ALGO_ETH  0.0003572000000000
#                          ALGO_EUR  0.0003572000000000
#                          ALGO_USD  0.0003572000000000
#                          ALGO_XBT  0.0003572000000000
#                          ATOM_ETH  0.0003572000000000
#                          ATOM_EUR  0.0003572000000000

# %%
shrimpy.

# %%
# Shrimpy Data Prep

def fetch_shrimpy_data():
    
    shrimpy_candles # 1m, 5m, 15m, 30m, 60m, 4h, 1d candles for universe of exchange Rates
    shrimpy_exchanges # kraken, coinbase pro, bittrex
    shrimpy_rates  # kraken, coinbase pro, bittrex available crypto exchange rates #

# %%
# CryptoCompare Data Prep

# %%
# NewsAPI Data Prep

# %%
# Twitter Data Prep
tweets = api_twitter.search('$SPY', count=200)
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
display(data.head(10))

#print(tweets[0].created_at)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1d5f94fe7953> in <module>
#       1 # Twitter Data Prep
# ----> 2 tweets = api_twitter.search('$SPY', count=200)
#       3 data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
#       4 display(data.head(10))
#       5
#
# NameError: name 'api_twitter' is not defined

# %% [markdown]
# # Factor Research Notebook
# ---

# %%
#Strategy Parameters (Global Variables)
exchanges = ['kraken', 'bittrex', 'coinbasepro']
ema_short_period = 9
ema_long_period = 21
RSI_period = 14
RSI_threshold_top = 70
RSI_threshold_bottom = 30
leverage = 0

# %%
def select_universe():
    return

def calc_factors():
    # Quantitative - Momentum, Mean Reversion
    def price_velocity():
        return price_velocity
    def price_acceleration():
        return price_acceleration
    

    def sentiment_velocity():
        return sentiment_velocity
    def sentiment_acceleration():
        return sentiment_acceleration


    def ema_cross():
        return ema_cross_signal
    def vol_cross():
        return vol_cross_signal
    def RSI():
        return rsi
    

    def PC_1():
        return PC_1
    def PC_2():
        return PC_2
    def PC_3():
        return PC_3

def make_pipeline():

    pipe =  Pipeline(
        columns={'M_Cap': ,
                 'price_velocity': ,
                 'price_acceleration': ,
                 'sentiment_velocity':,
                 'sentiment_acceleration':,
                 'ema_cross':,
                 'vol_cross':,
                 'RSI':,
                 'PC 1':,
                 'PC 2':,
                 'PC 3':,
                },
    screen = shrimpy_universe()
    )
    
    
    
    def onTick():
        return
    
    def rebalance():
        return
    def generate_target_position():
        return
    def unit_sizing():
        return
    
    def calc_performance_metrics():
        return
    def build_dashboard():
        return
    
    def kill_function():
        return

# %%
# Trading Functions
def position_size():

# %%
cryptocompare.get_coin_list()
# Out:
# {'BTCD': {'Id': '4400',
#   'Url': '/coins/btcd/overview',
#   'ImageUrl': '/media/19630/btcd_1.png',
#   'ContentCreatedOn': 1427711372,
#   'Name': 'BTCD',
#   'Symbol': 'BTCD',
#   'CoinName': 'BitcoinDark',
#   'FullName': 'BitcoinDark (BTCD)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '22000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '13',
#   'Sponsored': False,
#   'Taxonomy': {'Access': 'Permissionless',
#    'FCA': 'Exchange',
#    'FINMA': 'Payment',
#    'Industry': 'Financial and Insurance Activities',
#    'CollateralizedAsset': 'No',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CRAIG': {'Id': '4425',
#   'Url': '/coins/craig/overview',
#   'ImageUrl': '/media/20022/craig.png',
#   'ContentCreatedOn': 1427711632,
#   'Name': 'CRAIG',
#   'Symbol': 'CRAIG',
#   'CoinName': 'CraigsCoin',
#   'FullName': 'CraigsCoin (CRAIG)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '30000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '15',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'XBS': {'Id': '5023',
#   'Url': '/coins/xbs/overview',
#   'ImageUrl': '/media/351060/xbs_1.png',
#   'ContentCreatedOn': 1428671859,
#   'Name': 'XBS',
#   'Symbol': 'XBS',
#   'CoinName': 'Bitstake',
#   'FullName': 'Bitstake (XBS)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1300000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '16',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'XPY': {'Id': '5030',
#   'Url': '/coins/xpy/overview',
#   'ImageUrl': '/media/20076/xpy_1.png',
#   'ContentCreatedOn': 1428671950,
#   'Name': 'XPY',
#   'Symbol': 'XPY',
#   'CoinName': 'PayCoin',
#   'FullName': 'PayCoin (XPY)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '12500000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '17',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'PRC': {'Id': '3638',
#   'Url': '/coins/prc/overview',
#   'ImageUrl': '/media/20393/prc.png',
#   'ContentCreatedOn': 1424886122,
#   'Name': 'PRC',
#   'Symbol': 'PRC',
#   'CoinName': 'ProsperCoin',
#   'FullName': 'ProsperCoin (PRC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '21000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '18',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'YBC': {'Id': '3639',
#   'Url': '/coins/ybc/overview',
#   'ImageUrl': '/media/19975/ybc.png',
#   'ContentCreatedOn': 1424886292,
#   'Name': 'YBC',
#   'Symbol': 'YBC',
#   'CoinName': 'YbCoin',
#   'FullName': 'YbCoin (YBC)',
#   'Algorithm': 'Multiple',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '200000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '19',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'DANK': {'Id': '3640',
#   'Url': '/coins/dank/overview',
#   'ImageUrl': '/media/20247/dank.png',
#   'ContentCreatedOn': 1424886507,
#   'Name': 'DANK',
#   'Symbol': 'DANK',
#   'CoinName': 'DarkKush',
#   'FullName': 'DarkKush (DANK)',
#   'Algorithm': 'X13',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '3000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '20',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'GIVE': {'Id': '3641',
#   'Url': '/coins/give/overview',
#   'ImageUrl': '/media/20297/give.png',
#   'ContentCreatedOn': 1424889416,
#   'Name': 'GIVE',
#   'Symbol': 'GIVE',
#   'CoinName': 'GiveCoin',
#   'FullName': 'GiveCoin (GIVE)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '500000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '21',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'KOBO': {'Id': '3642',
#   'Url': '/coins/kobo/overview',
#   'ImageUrl': '/media/35521133/kobo.png',
#   'ContentCreatedOn': 1424944750,
#   'Name': 'KOBO',
#   'Symbol': 'KOBO',
#   'CoinName': 'KoboCoin',
#   'FullName': 'KoboCoin (KOBO)',
#   'Algorithm': 'X15',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '350000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '22',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'DT': {'Id': '3643',
#   'Url': '/coins/dt/overview',
#   'ImageUrl': '/media/20031/dt.png',
#   'ContentCreatedOn': 1424944815,
#   'Name': 'DT',
#   'Symbol': 'DT',
#   'CoinName': 'DarkToken',
#   'FullName': 'DarkToken (DT)',
#   'Algorithm': 'NIST5',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '23',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CETI': {'Id': '3644',
#   'Url': '/coins/ceti/overview',
#   'ImageUrl': '/media/20228/ceti.png',
#   'ContentCreatedOn': 1424944878,
#   'Name': 'CETI',
#   'Symbol': 'CETI',
#   'CoinName': 'CETUS Coin',
#   'FullName': 'CETUS Coin (CETI)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '24',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'SUP': {'Id': '3645',
#   'Url': '/coins/sup/overview',
#   'ImageUrl': '/media/20442/sup.png',
#   'ContentCreatedOn': 1424944957,
#   'Name': 'SUP',
#   'Symbol': 'SUP',
#   'CoinName': 'Supcoin',
#   'FullName': 'Supcoin (SUP)',
#   'Algorithm': 'N/A',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '25',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'XPD': {'Id': '3646',
#   'Url': '/coins/xpd/overview',
#   'ImageUrl': '/media/20162/xpd.png',
#   'ContentCreatedOn': 1424945008,
#   'Name': 'XPD',
#   'Symbol': 'XPD',
#   'CoinName': 'PetroDollar',
#   'FullName': 'PetroDollar (XPD)',
#   'Algorithm': 'SHA-256D',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '122107462',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '26',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'GEO': {'Id': '3647',
#   'Url': '/coins/geo/overview',
#   'ImageUrl': '/media/35309716/geo.png',
#   'ContentCreatedOn': 1424945068,
#   'Name': 'GEO',
#   'Symbol': 'GEO',
#   'CoinName': 'GeoCoin',
#   'FullName': 'GeoCoin (GEO)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '4000000',
#   'BuiltOn': '7605',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '27',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CHASH': {'Id': '3648',
#   'Url': '/coins/chash/overview',
#   'ImageUrl': '/media/20231/chash.png',
#   'ContentCreatedOn': 1424945076,
#   'Name': 'CHASH',
#   'Symbol': 'CHASH',
#   'CoinName': 'CleverHash',
#   'FullName': 'CleverHash (CHASH)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '28',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'NXTI': {'Id': '3650',
#   'Url': '/coins/nxti/overview',
#   'ImageUrl': '/media/20376/nxti.png',
#   'ContentCreatedOn': 1424952888,
#   'Name': 'NXTI',
#   'Symbol': 'NXTI',
#   'CoinName': 'NXTI',
#   'FullName': 'NXTI (NXTI)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': '1183',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '30',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'WOLF': {'Id': '3653',
#   'Url': '/coins/wolf/overview',
#   'ImageUrl': '/media/20559/wolf.png',
#   'ContentCreatedOn': 1424961410,
#   'Name': 'WOLF',
#   'Symbol': 'WOLF',
#   'CoinName': 'Insanity Coin',
#   'FullName': 'Insanity Coin (WOLF)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '50000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '31',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  '2015': {'Id': '3744',
#   'Url': '/coins/2015/overview',
#   'ImageUrl': '/media/20180/2015.png',
#   'ContentCreatedOn': 1425316878,
#   'Name': '2015',
#   'Symbol': '2015',
#   'CoinName': '2015 coin',
#   'FullName': '2015 coin (2015)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '33',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  '42': {'Id': '4321',
#   'Url': '/coins/42/overview',
#   'ImageUrl': '/media/35650717/42.jpg',
#   'ContentCreatedOn': 1427211129,
#   'Name': '42',
#   'Symbol': '42',
#   'CoinName': '42 Coin',
#   'FullName': '42 Coin (42)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '42',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '34',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ACOIN': {'Id': '4323',
#   'Url': '/coins/acoin/overview',
#   'ImageUrl': '/media/20079/acoin.png',
#   'ContentCreatedOn': 1427211494,
#   'Name': 'ACOIN',
#   'Symbol': 'ACOIN',
#   'CoinName': 'ACoin',
#   'FullName': 'ACoin (ACOIN)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1600000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '36',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'AERO': {'Id': '4324',
#   'Url': '/coins/aero/overview',
#   'ImageUrl': '/media/19594/aero.png',
#   'ContentCreatedOn': 1427211799,
#   'Name': 'AERO',
#   'Symbol': 'AERO',
#   'CoinName': 'Aero Coin',
#   'FullName': 'Aero Coin (AERO)',
#   'Algorithm': 'X13',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '7000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '37',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ALF': {'Id': '4325',
#   'Url': '/coins/alf/overview',
#   'ImageUrl': '/media/19600/alf.png',
#   'ContentCreatedOn': 1427212786,
#   'Name': 'ALF',
#   'Symbol': 'ALF',
#   'CoinName': 'AlphaCoin',
#   'FullName': 'AlphaCoin (ALF)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '210182000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '38',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'AGS': {'Id': '4326',
#   'Url': '/coins/ags/overview',
#   'ImageUrl': '/media/19595/ags.png',
#   'ContentCreatedOn': 1427212940,
#   'Name': 'AGS',
#   'Symbol': 'AGS',
#   'CoinName': 'Aegis',
#   'FullName': 'Aegis (AGS)',
#   'Algorithm': 'X13',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '39',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'AMC': {'Id': '4327',
#   'Url': '/coins/amc/overview',
#   'ImageUrl': '/media/19601/amc.png',
#   'ContentCreatedOn': 1427213123,
#   'Name': 'AMC',
#   'Symbol': 'AMC',
#   'CoinName': 'AmericanCoin',
#   'FullName': 'AmericanCoin (AMC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '168000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '40',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ALIEN': {'Id': '4328',
#   'Url': '/coins/alien/overview',
#   'ImageUrl': '/media/20080/aln.png',
#   'ContentCreatedOn': 1427213538,
#   'Name': 'ALIEN',
#   'Symbol': 'ALIEN',
#   'CoinName': 'AlienCoin',
#   'FullName': 'AlienCoin (ALIEN)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '200000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '41',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'APEX': {'Id': '4330',
#   'Url': '/coins/apex/overview',
#   'ImageUrl': '/media/19599/apex.png',
#   'ContentCreatedOn': 1427213810,
#   'Name': 'APEX',
#   'Symbol': 'APEX',
#   'CoinName': 'ApexCoin',
#   'FullName': 'ApexCoin (APEX)',
#   'Algorithm': 'X13',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '6000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '43',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ARCH': {'Id': '4331',
#   'Url': '/coins/arch/overview',
#   'ImageUrl': '/media/20085/arch.png',
#   'ContentCreatedOn': 1427213903,
#   'Name': 'ARCH',
#   'Symbol': 'ARCH',
#   'CoinName': 'ArchCoin',
#   'FullName': 'ArchCoin (ARCH)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '16403135',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '44',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ARG': {'Id': '4371',
#   'Url': '/coins/arg/overview',
#   'ImageUrl': '/media/19602/arg.png',
#   'ContentCreatedOn': 1427389495,
#   'Name': 'ARG',
#   'Symbol': 'ARG',
#   'CoinName': 'Argentum',
#   'FullName': 'Argentum (ARG)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '64000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '45',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ARI': {'Id': '4332',
#   'Url': '/coins/ari/overview',
#   'ImageUrl': '/media/20082/ari.png',
#   'ContentCreatedOn': 1427214031,
#   'Name': 'ARI',
#   'Symbol': 'ARI',
#   'CoinName': 'AriCoin',
#   'FullName': 'AriCoin (ARI)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '322649400',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '46',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'AXR': {'Id': '4334',
#   'Url': '/coins/axr/overview',
#   'ImageUrl': '/media/20086/axr.png',
#   'ContentCreatedOn': 1427214407,
#   'Name': 'AXR',
#   'Symbol': 'AXR',
#   'CoinName': 'AXRON',
#   'FullName': 'AXRON (AXR)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '48',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BET': {'Id': '4337',
#   'Url': '/coins/bet/overview',
#   'ImageUrl': '/media/19621/bet.png',
#   'ContentCreatedOn': 1427216740,
#   'Name': 'BET',
#   'Symbol': 'BET',
#   'CoinName': 'BetaCoin',
#   'FullName': 'BetaCoin (BET)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '32000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '51',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BEAN': {'Id': '4338',
#   'Url': '/coins/bean/overview',
#   'ImageUrl': '/media/350879/bitb.png',
#   'ContentCreatedOn': 1427216886,
#   'Name': 'BEAN',
#   'Symbol': 'BEAN',
#   'CoinName': 'BeanCash',
#   'FullName': 'BeanCash (BEAN)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '50000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '52',
#   'Sponsored': False,
#   'Taxonomy': {'Access': 'Permissionless',
#    'FCA': 'Exchange',
#    'FINMA': 'Payment',
#    'Industry': 'Financial and Insurance Activities',
#    'CollateralizedAsset': 'No',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BLU': {'Id': '4340',
#   'Url': '/coins/blu/overview',
#   'ImageUrl': '/media/19624/blu.png',
#   'ContentCreatedOn': 1427217771,
#   'Name': 'BLU',
#   'Symbol': 'BLU',
#   'CoinName': 'BlueCoin',
#   'FullName': 'BlueCoin (BLU)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '53',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BOST': {'Id': '4342',
#   'Url': '/coins/bost/overview',
#   'ImageUrl': '/media/19626/bost.png',
#   'ContentCreatedOn': 1427218233,
#   'Name': 'BOST',
#   'Symbol': 'BOST',
#   'CoinName': 'BoostCoin',
#   'FullName': 'BoostCoin (BOST)',
#   'Algorithm': 'X13',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '56',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BQC': {'Id': '4343',
#   'Url': '/coins/bqc/overview',
#   'ImageUrl': '/media/19631/bqc.png',
#   'ContentCreatedOn': 1427218365,
#   'Name': 'BQC',
#   'Symbol': 'BQC',
#   'CoinName': 'BQCoin',
#   'FullName': 'BQCoin (BQC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '88000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '57',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'XMY': {'Id': '4345',
#   'Url': '/coins/xmy/overview',
#   'ImageUrl': '/media/19815/myr.png',
#   'ContentCreatedOn': 1427224743,
#   'Name': 'XMY',
#   'Symbol': 'XMY',
#   'CoinName': 'MyriadCoin',
#   'FullName': 'MyriadCoin (XMY)',
#   'Algorithm': 'Multiple',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '2000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '58',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'MOON': {'Id': '4346',
#   'Url': '/coins/moon/overview',
#   'ImageUrl': '/media/19802/moon.png',
#   'ContentCreatedOn': 1427224814,
#   'Name': 'MOON',
#   'Symbol': 'MOON',
#   'CoinName': 'MoonCoin',
#   'FullName': 'MoonCoin (MOON)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '384000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '59',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ZET': {'Id': '4347',
#   'Url': '/coins/zet/overview',
#   'ImageUrl': '/media/19993/zet.png',
#   'ContentCreatedOn': 1427224896,
#   'Name': 'ZET',
#   'Symbol': 'ZET',
#   'CoinName': 'ZetaCoin',
#   'FullName': 'ZetaCoin (ZET)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '169795588',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '60',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'SXC': {'Id': '4348',
#   'Url': '/coins/sxc/overview',
#   'ImageUrl': '/media/19924/sxc.png',
#   'ContentCreatedOn': 1427224962,
#   'Name': 'SXC',
#   'Symbol': 'SXC',
#   'CoinName': 'SexCoin',
#   'FullName': 'SexCoin (SXC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '250000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '61',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'QTL': {'Id': '4349',
#   'Url': '/coins/qtl/overview',
#   'ImageUrl': '/media/19879/qtl.png',
#   'ContentCreatedOn': 1427225022,
#   'Name': 'QTL',
#   'Symbol': 'QTL',
#   'CoinName': 'Quatloo',
#   'FullName': 'Quatloo (QTL)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '100000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '62',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ENRG': {'Id': '4350',
#   'Url': '/coins/enrg/overview',
#   'ImageUrl': '/media/35650887/ezgifcom-resizejpg300.jpg',
#   'ContentCreatedOn': 1427225121,
#   'Name': 'ENRG',
#   'Symbol': 'ENRG',
#   'CoinName': 'EnergyCoin',
#   'FullName': 'EnergyCoin (ENRG)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '63',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'QRK': {'Id': '4351',
#   'Url': '/coins/qrk/overview',
#   'ImageUrl': '/media/19882/qrk.png',
#   'ContentCreatedOn': 1427225172,
#   'Name': 'QRK',
#   'Symbol': 'QRK',
#   'CoinName': 'QuarkCoin',
#   'FullName': 'QuarkCoin (QRK)',
#   'Algorithm': 'Quark',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '247000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '64',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': 'E-',
#     'TechnologyAdoptionRating': 'E-',
#     'MarketPerformanceRating': 'E-'}}},
#  'RIC': {'Id': '4352',
#   'Url': '/coins/ric/overview',
#   'ImageUrl': '/media/19888/ric.jpg',
#   'ContentCreatedOn': 1427225325,
#   'Name': 'RIC',
#   'Symbol': 'RIC',
#   'CoinName': 'Riecoin',
#   'FullName': 'Riecoin (RIC)',
#   'Algorithm': 'Groestl',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '84000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '65',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'DGC': {'Id': '4353',
#   'Url': '/coins/dgc/overview',
#   'ImageUrl': '/media/19676/dgc.png',
#   'ContentCreatedOn': 1427225687,
#   'Name': 'DGC',
#   'Symbol': 'DGC',
#   'CoinName': 'Digitalcoin ',
#   'FullName': 'Digitalcoin  (DGC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '48166000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '66',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'LIMX': {'Id': '4354',
#   'Url': '/coins/limx/overview',
#   'ImageUrl': '/media/19769/limx.png',
#   'ContentCreatedOn': 1427225826,
#   'Name': 'LIMX',
#   'Symbol': 'LIMX',
#   'CoinName': 'LimeCoinX',
#   'FullName': 'LimeCoinX (LIMX)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '21000000 ',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '67',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BTB': {'Id': '4399',
#   'Url': '/coins/btb/overview',
#   'ImageUrl': '/media/35650888/ezgifcom-resize.jpg',
#   'ContentCreatedOn': 1427711362,
#   'Name': 'BTB',
#   'Symbol': 'BTB',
#   'CoinName': 'BitBar',
#   'FullName': 'BitBar (BTB)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '500000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '69',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CAIX': {'Id': '4406',
#   'Url': '/coins/caix/overview',
#   'ImageUrl': '/media/20226/caix.png',
#   'ContentCreatedOn': 1427711432,
#   'Name': 'CAIx',
#   'Symbol': 'CAIX',
#   'CoinName': 'CAIx',
#   'FullName': 'CAIx (CAIx)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '0',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '70',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BTMK': {'Id': '4403',
#   'Url': '/coins/btmk/overview',
#   'ImageUrl': '/media/20084/btm.png',
#   'ContentCreatedOn': 1427711403,
#   'Name': 'BTMK',
#   'Symbol': 'BTMK',
#   'CoinName': 'BitMark',
#   'FullName': 'BitMark (BTMK)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '27580000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '73',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BUK': {'Id': '4404',
#   'Url': '/coins/buk/overview',
#   'ImageUrl': '/media/19637/buk.png',
#   'ContentCreatedOn': 1427711413,
#   'Name': 'BUK',
#   'Symbol': 'BUK',
#   'CoinName': 'CryptoBuk',
#   'FullName': 'CryptoBuk (BUK)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '100000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '74',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CACH': {'Id': '4405',
#   'Url': '/coins/cach/overview',
#   'ImageUrl': '/media/35650889/ezgifcom-resize-1.jpg',
#   'ContentCreatedOn': 1427711423,
#   'Name': 'CACH',
#   'Symbol': 'CACH',
#   'CoinName': 'Cachecoin',
#   'FullName': 'Cachecoin (CACH)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '2000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '75',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CANN': {'Id': '4407',
#   'Url': '/coins/cann/overview',
#   'ImageUrl': '/media/20015/cann.png',
#   'ContentCreatedOn': 1427711443,
#   'Name': 'CANN',
#   'Symbol': 'CANN',
#   'CoinName': 'CannabisCoin',
#   'FullName': 'CannabisCoin (CANN)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '76',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CAP': {'Id': '4408',
#   'Url': '/coins/cap/overview',
#   'ImageUrl': '/media/20017/cap.png',
#   'ContentCreatedOn': 1427711454,
#   'Name': 'CAP',
#   'Symbol': 'CAP',
#   'CoinName': 'BottleCaps',
#   'FullName': 'BottleCaps (CAP)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '47433600',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '77',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CASH': {'Id': '4409',
#   'Url': '/coins/cash/overview',
#   'ImageUrl': '/media/20016/cash.png',
#   'ContentCreatedOn': 1427711464,
#   'Name': 'CASH',
#   'Symbol': 'CASH',
#   'CoinName': 'CashCoin',
#   'FullName': 'CashCoin (CASH)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '47433600',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '78',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CAT': {'Id': '4410',
#   'Url': '/coins/cat/overview',
#   'ImageUrl': '/media/35521144/cat.png',
#   'ContentCreatedOn': 1427711475,
#   'Name': 'CAT',
#   'Symbol': 'CAT',
#   'CoinName': 'Catcoin',
#   'FullName': 'Catcoin (CAT)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '21000000 ',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '79',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CBX': {'Id': '4411',
#   'Url': '/coins/cbx/overview',
#   'ImageUrl': '/media/30001996/cbx.png',
#   'ContentCreatedOn': 1427711486,
#   'Name': 'CBX',
#   'Symbol': 'CBX',
#   'CoinName': 'CryptoBullion',
#   'FullName': 'CryptoBullion (CBX)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '80',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CCN': {'Id': '4412',
#   'Url': '/coins/ccn/overview',
#   'ImageUrl': '/media/19643/ccn.png',
#   'ContentCreatedOn': 1427711494,
#   'Name': 'CCN',
#   'Symbol': 'CCN',
#   'CoinName': 'CannaCoin',
#   'FullName': 'CannaCoin (CCN)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '13140000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '81',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CIN': {'Id': '4413',
#   'Url': '/coins/cin/overview',
#   'ImageUrl': '/media/20698/cinder.png',
#   'ContentCreatedOn': 1427711504,
#   'Name': 'CIN',
#   'Symbol': 'CIN',
#   'CoinName': 'CinderCoin',
#   'FullName': 'CinderCoin (CIN)',
#   'Algorithm': 'Multiple',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '114000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '82',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CINNI': {'Id': '4414',
#   'Url': '/coins/cinni/overview',
#   'ImageUrl': '/media/19651/cinni.jpeg',
#   'ContentCreatedOn': 1427711514,
#   'Name': 'CINNI',
#   'Symbol': 'CINNI',
#   'CoinName': 'CINNICOIN',
#   'FullName': 'CINNICOIN (CINNI)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '15000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '83',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CXC': {'Id': '4415',
#   'Url': '/coins/cxc/overview',
#   'ImageUrl': '/media/20246/cxc.png',
#   'ContentCreatedOn': 1427711523,
#   'Name': 'CXC',
#   'Symbol': 'CXC',
#   'CoinName': 'CheckCoin',
#   'FullName': 'CheckCoin (CXC)',
#   'Algorithm': 'N/A',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '100000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '84',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CLAM': {'Id': '4416',
#   'Url': '/coins/clam/overview',
#   'ImageUrl': '/media/20020/clam.png',
# ...
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'WSX': {'Id': '68084',
#   'Url': '/coins/wsx/overview',
#   'ImageUrl': '/media/1383144/wsx.png',
#   'ContentCreatedOn': 1493969319,
#   'Name': 'WSX',
#   'Symbol': 'WSX',
#   'CoinName': 'WeAreSatoshi',
#   'FullName': 'WeAreSatoshi (WSX)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1190',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'IEC': {'Id': '68088',
#   'Url': '/coins/iec/overview',
#   'ImageUrl': '/media/1383144/wsx.png',
#   'ContentCreatedOn': 1493969945,
#   'Name': 'IEC',
#   'Symbol': 'IEC',
#   'CoinName': 'IvugeoEvolutionCoin',
#   'FullName': 'IvugeoEvolutionCoin (IEC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '100000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1191',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'IMS': {'Id': '68093',
#   'Url': '/coins/ims/overview',
#   'ImageUrl': '/media/1383145/ims.png',
#   'ContentCreatedOn': 1493970340,
#   'Name': 'IMS',
#   'Symbol': 'IMS',
#   'CoinName': 'Independent Money System',
#   'FullName': 'Independent Money System (IMS)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '21212121',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1192',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'ARGUS': {'Id': '70352',
#   'Url': '/coins/argus/overview',
#   'ImageUrl': '/media/1383149/argus.png',
#   'ContentCreatedOn': 1494260582,
#   'Name': 'ARGUS',
#   'Symbol': 'ARGUS',
#   'CoinName': 'ArgusCoin',
#   'FullName': 'ArgusCoin (ARGUS)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '28600000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1194',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'CNT': {'Id': '70365',
#   'Url': '/coins/cnt/overview',
#   'ImageUrl': '/media/1383150/cnt.png',
#   'ContentCreatedOn': 1494261444,
#   'Name': 'CNT',
#   'Symbol': 'CNT',
#   'CoinName': 'Centurion',
#   'FullName': 'Centurion (CNT)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1195',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'LMC': {'Id': '70469',
#   'Url': '/coins/lmc/overview',
#   'ImageUrl': '/media/1383139/lmc.png',
#   'ContentCreatedOn': 1494270042,
#   'Name': 'LMC',
#   'Symbol': 'LMC',
#   'CoinName': 'LomoCoin',
#   'FullName': 'LomoCoin (LMC)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1196',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'TKN': {'Id': '71077',
#   'Url': '/coins/tkn/overview',
#   'ImageUrl': '/media/1383157/tkn.png',
#   'ContentCreatedOn': 1494337298,
#   'Name': 'TKN',
#   'Symbol': 'TKN',
#   'CoinName': 'Monolith',
#   'FullName': 'Monolith (TKN)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '39406760',
#   'BuiltOn': '7605',
#   'SmartContractAddress': '0xaaaf91d9b90df800df4f55c205fd6989c977e73a',
#   'DecimalPlaces': 8,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1197',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BTCS': {'Id': '71321',
#   'Url': '/coins/btcs/overview',
#   'ImageUrl': '/media/1383158/btcs.png',
#   'ContentCreatedOn': 1494358830,
#   'Name': 'BTCS',
#   'Symbol': 'BTCS',
#   'CoinName': 'Bitcoin Scrypt',
#   'FullName': 'Bitcoin Scrypt (BTCS)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '21000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1198',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'PROC': {'Id': '71334',
#   'Url': '/coins/proc/overview',
#   'ImageUrl': '/media/1383159/proc.png',
#   'ContentCreatedOn': 1494359683,
#   'Name': 'PROC',
#   'Symbol': 'PROC',
#   'CoinName': 'ProCurrency',
#   'FullName': 'ProCurrency (PROC)',
#   'Algorithm': 'SHA-256',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '75000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1199',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'XGR': {'Id': '71862',
#   'Url': '/coins/xgr/overview',
#   'ImageUrl': '/media/1383161/xgr.png',
#   'ContentCreatedOn': 1494425942,
#   'Name': 'XGR',
#   'Symbol': 'XGR',
#   'CoinName': 'GoldReserve',
#   'FullName': 'GoldReserve (XGR)',
#   'Algorithm': 'X11',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '40000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1200',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BENJI': {'Id': '71884',
#   'Url': '/coins/benji/overview',
#   'ImageUrl': '/media/1383163/benji.png',
#   'ContentCreatedOn': 1494427405,
#   'Name': 'BENJI',
#   'Symbol': 'BENJI',
#   'CoinName': 'BenjiRolls',
#   'FullName': 'BenjiRolls (BENJI)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '35520400',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1202',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'HMQ': {'Id': '72438',
#   'Url': '/coins/hmq/overview',
#   'ImageUrl': '/media/1383174/hmq.png',
#   'ContentCreatedOn': 1494504147,
#   'Name': 'HMQ',
#   'Symbol': 'HMQ',
#   'CoinName': 'Humaniq',
#   'FullName': 'Humaniq (HMQ)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': '7605',
#   'SmartContractAddress': '0xcbcc0f036ed4788f63fc0fee32873d6a7487b908',
#   'DecimalPlaces': 8,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1203',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'BCAP': {'Id': '72955',
#   'Url': '/coins/bcap/overview',
#   'ImageUrl': '/media/1383948/bcap1.png',
#   'ContentCreatedOn': 1494573629,
#   'Name': 'BCAP',
#   'Symbol': 'BCAP',
#   'CoinName': 'Blockchain Capital',
#   'FullName': 'Blockchain Capital (BCAP)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '10000000',
#   'BuiltOn': '7605',
#   'SmartContractAddress': '0xff3519eeeea3e76f1f699ccce5e23ee0bdda41ac',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1204',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'DUO': {'Id': '73132',
#   'Url': '/coins/duo/overview',
#   'ImageUrl': '/media/35651032/para300x300.png',
#   'ContentCreatedOn': 1494597733,
#   'Name': 'DUO',
#   'Symbol': 'DUO',
#   'CoinName': 'ParallelCoin',
#   'FullName': 'ParallelCoin (DUO)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1205',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'RBX': {'Id': '73143',
#   'Url': '/coins/rbx/overview',
#   'ImageUrl': '/media/1383197/rbx.png',
#   'ContentCreatedOn': 1494598920,
#   'Name': 'RBX',
#   'Symbol': 'RBX',
#   'CoinName': 'RiptoBuX',
#   'FullName': 'RiptoBuX (RBX)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': '20131',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 8,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1206',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'GRW': {'Id': '74894',
#   'Url': '/coins/grw/overview',
#   'ImageUrl': '/media/1383234/grw.png',
#   'ContentCreatedOn': 1494861198,
#   'Name': 'GRW',
#   'Symbol': 'GRW',
#   'CoinName': 'GrowthCoin',
#   'FullName': 'GrowthCoin (GRW)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '2000000000',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1207',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'APX': {'Id': '74912',
#   'Url': '/coins/apx/overview',
#   'ImageUrl': '/media/1383235/apx.png',
#   'ContentCreatedOn': 1494863011,
#   'Name': 'APX',
#   'Symbol': 'APX',
#   'CoinName': 'Apx',
#   'FullName': 'Apx (APX)',
#   'Algorithm': 'N/A',
#   'ProofType': 'N/A',
#   'FullyPremined': '0',
#   'TotalCoinSupply': '1000000',
#   'BuiltOn': '28652',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1208',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'MILO': {'Id': '74924',
#   'Url': '/coins/milo/overview',
#   'ImageUrl': '/media/1383236/milo.png',
#   'ContentCreatedOn': 1494863783,
#   'Name': 'MILO',
#   'Symbol': 'MILO',
#   'CoinName': 'MiloCoin',
#   'FullName': 'MiloCoin (MILO)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1209',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  'OLV': {'Id': '75285',
#   'Url': '/coins/olv/overview',
#   'ImageUrl': '/media/1383239/xvs.png',
#   'ContentCreatedOn': 1494912733,
#   'Name': 'OLV',
#   'Symbol': 'OLV',
#   'CoinName': 'OldV',
#   'FullName': 'OldV (OLV)',
#   'Algorithm': 'Scrypt',
#   'ProofType': 'PoW/PoS',
#   'FullyPremined': '0',
#   'TotalCoinSupply': 'N/A',
#   'BuiltOn': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'DecimalPlaces': 0,
#   'PreMinedValue': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'SortOrder': '1210',
#   'Sponsored': False,
#   'Taxonomy': {'Access': '',
#    'FCA': '',
#    'FINMA': '',
#    'Industry': '',
#    'CollateralizedAsset': '',
#    'CollateralizedAssetType': '',
#    'CollateralType': '',
#    'CollateralInfo': ''},
#   'Rating': {'Weiss': {'Rating': '',
#     'TechnologyAdoptionRating': '',
#     'MarketPerformanceRating': ''}}},
#  ...}

# %% [markdown]
# # ML Trading Models
# ---

# %%
# Design Signal Features

# %%
# Train Model

# %%
# Trade Model

# %%
dump(random_forest_model, 'random_forest_model.joblib')
dump(gradient_booster_model, 'gradient_booster_model.joblib')
dump()

# %% [markdown]
# ## Algorithmic Trading Framework
# ---

# %%
def initialize(cash=None):
    """Initialize the dashboard, data storage, and account balances."""
    print("Initializing Account and DataFrame")
    #Initialize Account
    account = {"balance": btc, "tokens":0}
    #Initalize dataframes
    df = fetch_data()
    return account, df


def build_dashboard(signals_df, portfolio_evaluation_df):
    """Build the dashboard."""
    # Create hvplot visualizations
    price_df = signals_df[["close", "SMA50", "SMA100"]]
    price_chart = price_df.hvplot.line().opts(xaxis=None)
    portfolio_evaluation_table = portfolio_evaluation_df.hvplot.table(
        columns=["index", "Backtest"]
    )

    # Build the dashboard
    dashboard = pn.Column(
        "# Trading Dashboard", price_chart, portfolio_evaluation_table
    )
    return dashboard


def fetch_data():
    """Fetches the latest prices."""
    # Set the file path and read CSV into a Pandas DataFrame
    filepath = Path("../Resources/aapl.csv")
    data_df = pd.read_csv(filepath)

    # Print the DataFrame
    print(data_df.head())
    return data_df


def generate_signals(data_df):
    """Generates trading signals for a given dataset."""
    # Grab just the `date` and `close` from the dataset
    signals_df = data_df.loc[:, ["date", "close"]].copy()

    # Set the `date` column as the index
    signals_df = signals_df.set_index("date", drop=True)

    # Set the short window and long windows
    short_window = 50
    long_window = 100

    # Generate the short and long moving averages (50 and 100 days, respectively)
    signals_df["SMA50"] = signals_df["close"].rolling(window=short_window).mean()
    signals_df["SMA100"] = signals_df["close"].rolling(window=long_window).mean()
    signals_df["Signal"] = 0.0

    # Generate the trading signal 0 or 1,
    # where 0 is when the SMA50 is under the SMA100, and
    # where 1 is when the SMA50 is higher (or crosses over) the SMA100
    signals_df["Signal"][short_window:] = np.where(
        signals_df["SMA50"][short_window:] > signals_df["SMA100"][short_window:],
        1.0,
        0.0,
    )

    # Calculate the points in time at which a position should be taken, 1 or -1
    signals_df["Entry/Exit"] = signals_df["Signal"].diff()

    return signals_df


def execute_backtest(signals_df):
    """Backtests signal data."""
    # Set initial capital
    initial_capital = float(100000)

    # Set the share size
    share_size = 500

    # Take a 500 share position where the dual moving average crossover is 1 (SMA50 is greater than SMA100)
    signals_df["Position"] = share_size * signals_df["Signal"]

    # Find the points in time where a 500 share position is bought or sold
    signals_df["Entry/Exit Position"] = signals_df["Position"].diff()

    # Multiply share price by entry/exit positions and get the cumulatively sum
    signals_df["Portfolio Holdings"] = (
        signals_df["close"] * signals_df["Entry/Exit Position"].cumsum()
    )

    # Subtract the initial capital by the portfolio holdings to get the amount of liquid cash in the portfolio
    signals_df["Portfolio Cash"] = (
        initial_capital
        - (signals_df["close"] * signals_df["Entry/Exit Position"]).cumsum()
    )

    # Get the total portfolio value by adding the cash amount by the portfolio holdings (or investments)
    signals_df["Portfolio Total"] = (
        signals_df["Portfolio Cash"] + signals_df["Portfolio Holdings"]
    )

    # Calculate the portfolio daily returns
    signals_df["Portfolio Daily Returns"] = signals_df["Portfolio Total"].pct_change()

    # Calculate the cumulative returns
    signals_df["Portfolio Cumulative Returns"] = (
        1 + signals_df["Portfolio Daily Returns"]
    ).cumprod() - 1

    return signals_df


def execute_trade_strategy():
    """Makes a buy/sell/hold decision."""
    # @TODO: We will complete this later!
    
    pass


def evaluate_metrics(signals_df):
    """Generates evaluation metrics from backtested signal data."""
    # Prepare DataFrame for metrics
    metrics = [
        "Annual Return",
        "Cumulative Returns",
        "Annual Volatility",
        "Sharpe Ratio",
        "Sortino Ratio",
    ]

    columns = ["Backtest"]

    # Initialize the DataFrame with index set to evaluation metrics and column as `Backtest` (just like PyFolio)
    portfolio_evaluation_df = pd.DataFrame(index=metrics, columns=columns)

    # Calculate cumulative return
    portfolio_evaluation_df.loc["Cumulative Returns"] = signals_df[
        "Portfolio Cumulative Returns"
    ][-1]

    # Calculate annualized return
    portfolio_evaluation_df.loc["Annual Return"] = (
        signals_df["Portfolio Daily Returns"].mean() * 252
    )

    # Calculate annual volatility
    portfolio_evaluation_df.loc["Annual Volatility"] = (
        1 + signals_df["Portfolio Daily Returns"].std() * np.sqrt(252)
    )

    # Calculate Sharpe Ratio
    portfolio_evaluation_df.loc["Sharpe Ratio"] = (
        signals_df["Portfolio Daily Returns"].mean() * 252
    ) / (signals_df["Portfolio Daily Returns"].std() * np.sqrt(252))

    # Calculate Downside Return
    sortino_ratio_df = signals_df[["Portfolio Daily Returns"]].copy()
    sortino_ratio_df.loc[:, "Downside Returns"] = 0

    target = 0
    mask = sortino_ratio_df["Portfolio Daily Returns"] < target
    sortino_ratio_df.loc[mask, "Downside Returns"] = (
        sortino_ratio_df["Portfolio Daily Returns"] ** 2
    )
    portfolio_evaluation_df

    # Calculate Sortino Ratio
    down_stdev = np.sqrt(sortino_ratio_df["Downside Returns"].mean()) * np.sqrt(252)
    expected_return = sortino_ratio_df["Portfolio Daily Returns"].mean() * 252
    sortino_ratio = expected_return / down_stdev

    portfolio_evaluation_df.loc["Sortino Ratio"] = sortino_ratio

    return portfolio_evaluation_df


def main():
    """Main Event Loop."""
    data_df = fetch_data()
    signals_df = generate_signals(data_df)
    tested_signals_df = execute_backtest(signals_df)
    portfolio_evaluation_df = evaluate_metrics(tested_signals_df)
    dashboard = build_dashboard(tested_signals_df, portfolio_evaluation_df)
    dashboard.servable()
    return


main()
